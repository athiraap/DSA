# %% [markdown]
# **1. Read the dataset to Python environment:**

# %%
import pandas as pd
file_path = '/home/nandu/Downloads/iris.xls'
df = pd.read_excel(file_path)
print(df.head())
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %% [markdown]
# **2. Display the columns in the dataset:**

# %%
import pandas as pd
file_path = '/home/nandu/Downloads/iris.xls'
df = pd.read_excel(file_path)
print("Columns in the dataset:")
print(df.columns)
# Out:
# Columns in the dataset:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# **3. Calculate the mean of each column of the dataset:**

# %%
import pandas as pd
file_path = '/home/nandu/Downloads/iris.xls'
df = pd.read_excel(file_path)
column_means = df.mean()
print("Mean of each column:")
print(column_means)
# Out:
# Mean of each column:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64
# /tmp/ipykernel_7743/4195477113.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   column_means = df.mean()

# %% [markdown]
# **4. Check for the null values present in the dataset:**

# %%
import pandas as pd
file_path = '/home/nandu/Downloads/iris.xls'
df = pd.read_excel(file_path)
null_values = df.isnull().sum()
print("Null values in each column:")
print(null_values)
# Out:
# Null values in each column:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# **5. Perform meaningful visualizations using the dataset. Bring at least 3
# visualizations:**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
file_path = '/home/nandu/Downloads/iris.xls'
df = pd.read_excel(file_path)

# Visualization 1: Pairplot
sns.pairplot(df, hue='Classification', markers='o')
plt.title('Pairplot of Iris Dataset')
plt.show()

# Visualization 2: Boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x='Classification', y='SL', data=df)
plt.title('Boxplot of Sepal Length by Classification')
plt.show()

# Visualization 3: Heatmap (Correlation Matrix)
correlation_matrix = df.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Matrix of Iris Dataset')
plt.show()
